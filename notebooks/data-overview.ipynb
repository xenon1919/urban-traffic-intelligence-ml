# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Load the dataset

# %%
df = pd.read_csv("../data/urban_traffic_intelligence_dataset.csv")
df.head()
# Out:
#    road_id  hour  day_of_week  is_weekend road_type  lane_count weather  \
# 0      103    11            0           0   Highway           5    Rain
# 1       52     1            0           0     Local           1   Clear
# 2       93    17            5           1   Highway           5   Clear
# 3       15     6            6           1   Highway           5    Rain
# 4      107    16            4           0   Highway           4   Clear
#
#    visibility_km  accident_reported  traffic_volume  avg_speed  \
# 0       4.700783                  0             130  43.962934
# 1       6.237843                  0             393  69.132264
# 2       6.251072                  0            1225  42.718578
# 3       2.344686                  0             301  33.536640
# 4       6.657439                  0             273  31.774258
#
#    travel_time_min congestion_level
# 0        17.303469              Low
# 1        17.131562              Low
# 2        40.431364             High
# ...

# %%
df.shape
# Out:
# (12000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   road_id            12000 non-null  int64
#  1   hour               12000 non-null  int64
#  2   day_of_week        12000 non-null  int64
#  3   is_weekend         12000 non-null  int64
#  4   road_type          12000 non-null  object
#  5   lane_count         12000 non-null  int64
#  6   weather            12000 non-null  object
#  7   visibility_km      12000 non-null  float64
#  8   accident_reported  12000 non-null  int64
#  9   traffic_volume     12000 non-null  int64
#  10  avg_speed          12000 non-null  float64
#  11  travel_time_min    12000 non-null  float64
#  12  congestion_level   12000 non-null  object
# dtypes: float64(3), int64(7), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Project Objective
#
# This project aims to build a traffic intelligence system using machine learning.
#
# ### Supervised Learning Tasks
# 1. Regression: Predict travel time (`travel_time_min`)
# 2. Classification: Predict congestion level (`congestion_level`)
#
# ### Unsupervised Learning Task
# - Discover traffic patterns using clustering techniques

# %% [markdown]
# # Feature & Target Separation

# %%
features = df.drop(
    ["travel_time_min", "congestion_level"], axis=1
)

targets = df[["travel_time_min", "congestion_level"]]

features.head(), targets.head()
# Out:
# (   road_id  hour  day_of_week  is_weekend road_type  lane_count weather  \
#  0      103    11            0           0   Highway           5    Rain
#  1       52     1            0           0     Local           1   Clear
#  2       93    17            5           1   Highway           5   Clear
#  3       15     6            6           1   Highway           5    Rain
#  4      107    16            4           0   Highway           4   Clear
#
#     visibility_km  accident_reported  traffic_volume  avg_speed
#  0       4.700783                  0             130  43.962934
#  1       6.237843                  0             393  69.132264
#  2       6.251072                  0            1225  42.718578
#  3       2.344686                  0             301  33.536640
#  4       6.657439                  0             273  31.774258  ,
#     travel_time_min congestion_level
#  0        17.303469              Low
#  1        17.131562              Low
# ...

# %% [markdown]
# ## Model Strategy
#
# - Linear/Logistic Regression: High bias baseline
# - Decision Trees: High variance model
# - Random Forest & XGBoost: Bias–variance balance
# - KNN & SVM: Distance and margin-based learning

# %% [markdown]
# ## Evaluation Metrics
#
# ### Regression
# - RMSE
# - MAE
#
# ### Classification
# - Precision
# - Recall
# - F1-score
# - ROC-AUC
